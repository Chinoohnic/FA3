# %% [markdown]
# <a href="https://colab.research.google.com/github/Chinoohnic/FA3/blob/main/Problem2_Loan_Eligibility.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
credit_score = int(input("Enter credit score: "))
income = float(input("Enter annual income: "))
years = float(input("Enter years at current job: "))

if credit_score >= 700 and income >= 30000 and years >= 2:
    print("Result: Loan Approved")
else:
    print("Result: Loan Denied")
